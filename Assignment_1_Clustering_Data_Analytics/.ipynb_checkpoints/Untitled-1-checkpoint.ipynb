# %% [markdown]
# # Setup
# import os
# import pandas as pd
# import tempfile
#
# # Create directories for trial_pp and trial_itt
# trial_pp_dir = os.path.join(tempfile.gettempdir(), "trial_pp")
# os.makedirs(trial_pp_dir, exist_ok=True)
#
# trial_itt_dir = os.path.join(tempfile.gettempdir(), "trial_itt")
# os.makedirs(trial_itt_dir, exist_ok=True)
#
# # Placeholder functions for trial_sequence and model fitting
# def trial_sequence(estimand):
#     return {"estimand": estimand}

# %%
import os
import pandas as pd
import tempfile

# Create directories for trial_pp and trial_itt
trial_pp_dir = os.path.join(tempfile.gettempdir(), "trial_pp")
os.makedirs(trial_pp_dir, exist_ok=True)

trial_itt_dir = os.path.join(tempfile.gettempdir(), "trial_itt")
os.makedirs(trial_itt_dir, exist_ok=True)

# Placeholder functions for trial_sequence and model fitting
def trial_sequence(estimand):
    return {"estimand": estimand}

# %% [markdown]
# # Data Preparation
# data_censored = pd.read_csv('c:/Users/USER/Documents/3rd year 2nd sem/Data Analytics/Assignments_Data_Analytics/Assignment_1_Clustering_Data_Analytics/data_censored.csv')
# print(data_censored.head())
#
# # Per-protocol
# trial_pp = trial_sequence(estimand="PP")
# trial_pp = set_data(
#     trial_pp,
#     data=data_censored,
#     id="id",
#     period="period",
#     treatment="treatment",
#     outcome="outcome",
#     eligible="eligible"
# )
#
# # ITT
# trial_itt = trial_sequence(estimand="ITT")
# trial_itt = set_data(
#     trial_itt,
#     data=data_censored,
#     id="id",
#     period="period",
#     treatment="treatment",
#     outcome="outcome",
#     eligible="eligible"
# )

# %%
# Load the data from the CSV file
data_censored = pd.read_csv('c:/Users/USER/Documents/3rd year 2nd sem/Data Analytics/Assignments_Data_Analytics/Assignment_1_Clustering_Data_Analytics/data_censored.csv')
print(data_censored.head())

# Per-protocol
trial_pp = trial_sequence(estimand="PP")
trial_pp = set_data(
    trial_pp,
    data=data_censored,
    id="id",
    period="period",
    treatment="treatment",
    outcome="outcome",
    eligible="eligible"
)

# ITT
trial_itt = trial_sequence(estimand="ITT")
trial_itt = set_data(
    trial_itt,
    data=data_censored,
    id="id",
    period="period",
    treatment="treatment",
    outcome="outcome",
    eligible="eligible"
)

# %% [markdown]
# # Weight Models and Censoring
# # Placeholder functions for model fitting
# def stats_glm_logit(save_path):
#     return f"Model fitter with save path: {save_path}"
#
# def set_switch_weight_model(trial, numerator, denominator, model_fitter):
#     trial["switch_weight_model"] = {
#         "numerator": numerator,
#         "denominator": denominator,
#         "model_fitter": model_fitter
#     }
#     return trial
#
# def set_censor_weight_model(trial, censor_event, numerator, denominator, pool_models, model_fitter):
#     trial["censor_weight_model"] = {
#         "censor_event": censor_event,
#         "numerator": numerator,
#         "denominator": denominator,
#         "pool_models": pool_models,
#         "model_fitter": model_fitter
#     }
#     return trial

# %%
# Placeholder functions for model fitting
def stats_glm_logit(save_path):
    return f"Model fitter with save path: {save_path}"

def set_switch_weight_model(trial, numerator, denominator, model_fitter):
    trial["switch_weight_model"] = {
        "numerator": numerator,
        "denominator": denominator,
        "model_fitter": model_fitter
    }
    return trial

def set_censor_weight_model(trial, censor_event, numerator, denominator, pool_models, model_fitter):
    trial["censor_weight_model"] = {
        "censor_event": censor_event,
        "numerator": numerator,
        "denominator": denominator,
        "pool_models": pool_models,
        "model_fitter": model_fitter
    }
    return trial

# Set switch weight model for trial_pp
trial_pp = set_switch_weight_model(
    trial_pp,
    numerator="age",
    denominator="age + x1 + x3",
    model_fitter=stats_glm_logit(save_path=os.path.join(trial_pp_dir, "switch_models"))
)

# Set censor weight model for trial_pp
trial_pp = set_censor_weight_model(
    trial_pp,
    censor_event="censored",
    numerator="~ x2",
    denominator="~ x2 + x1",
    pool_models="none",
    model_fitter=stats_glm_logit(save_path=os.path.join(trial_pp_dir, "censor_models"))
)

# Set censor weight model for trial_itt
trial_itt = set_censor_weight_model(
    trial_itt,
    censor_event="censored",
    numerator="~ x2",
    denominator="~ x2 + x1",
    pool_models="numerator",
    model_fitter=stats_glm_logit(save_path=os.path.join(trial_itt_dir, "censor_models"))
)

# %% [markdown]
# # Censoring Due to Treatment Switching
# trial_pp = set_switch_weight_model(
#     trial_pp,
#     numerator="age",
#     denominator="age + x1 + x3",
#     model_fitter=stats_glm_logit(save_path=os.path.join(trial_pp_dir, "switch_models"))
# )
# print(trial_pp["switch_weight_model"])

# %%
# Set switch weight model for trial_pp
trial_pp = set_switch_weight_model(
    trial_pp,
    numerator="age",
    denominator="age + x1 + x3",
    model_fitter=stats_glm_logit(save_path=os.path.join(trial_pp_dir, "switch_models"))
)

# Print the switch weights model
print(trial_pp["switch_weight_model"])

# %% [markdown]
# # Other Informative Censoring
# trial_pp = set_censor_weight_model(
#     trial_pp,
#     censor_event="censored",
#     numerator="~ x2",
#     denominator="~ x2 + x1",
#     pool_models="none",
#     model_fitter=stats_glm_logit(save_path=os.path.join(trial_pp_dir, "censor_models"))
# )
# print(trial_pp["censor_weight_model"])
#
# trial_itt = set_censor_weight_model(
#     trial_itt,
#     censor_event="censored",
#     numerator="~ x2",
#     denominator="~ x2 + x1",
#     pool_models="numerator",
#     model_fitter=stats_glm_logit(save_path=os.path.join(trial_itt_dir, "censor_models"))
# )
# print(trial_itt["censor_weight_model"])

# %%
# Set censor weight model for trial_pp
trial_pp = set_censor_weight_model(
    trial_pp,
    censor_event="censored",
    numerator="~ x2",
    denominator="~ x2 + x1",
    pool_models="none",
    model_fitter=stats_glm_logit(save_path=os.path.join(trial_pp_dir, "censor_models"))
)
print(trial_pp["censor_weight_model"])

# Set censor weight model for trial_itt
trial_itt = set_censor_weight_model(
    trial_itt,
    censor_event="censored",
    numerator="~ x2",
    denominator="~ x2 + x1",
    pool_models="numerator",
    model_fitter=stats_glm_logit(save_path=os.path.join(trial_itt_dir, "censor_models"))
)
print(trial_itt["censor_weight_model"])

# %% [markdown]
# # Calculate Weights
# # Placeholder function for calculating weights
# def calculate_weights(trial):
#     return trial
#
# trial_pp = calculate_weights(trial_pp)
# trial_itt = calculate_weights(trial_itt)

# %%
# Placeholder function for calculating weights
def calculate_weights(trial):
    return trial

trial_pp = calculate_weights(trial_pp)
trial_itt = calculate_weights(trial_itt)
